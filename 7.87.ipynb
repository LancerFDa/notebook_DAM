# %%
# File mergedexc.py (Python 3.X + 2.X)
sep = '-' * 45 + '\n'

print(sep + 'EXCEPTION RAISED AND CAUGHT')
try:
    x = 'spam'[99]
except IndexError:
    print('except run')
finally:
    print('finally run')
print('after run')

print(sep + 'NO EXCEPTION RAISED')
try:
    x = 'spam'[3]
except IndexError:
    print('except run')
finally:
    print('finally run')
print('after run')

print(sep + 'NO EXCEPTION RAISED, WITH ELSE')
try:
    x = 'spam'[3]
except IndexError:
    print('except run')
else:
    print('else run')
finally:
    print('finally run')
print('after run')

print(sep + 'EXCEPTION RAISED BUT NOT CAUGHT')
try:
    x = 1 / 0
except IndexError:
    print('except run')
finally:
    print('finally run')
print('after run')
# Out:
# ---------------------------------------------
# EXCEPTION RAISED AND CAUGHT
# except run
# finally run
# after run
# ---------------------------------------------
# NO EXCEPTION RAISED
# finally run
# after run
# ---------------------------------------------
# NO EXCEPTION RAISED, WITH ELSE
# else run
# finally run
# after run
# ---------------------------------------------
# EXCEPTION RAISED BUT NOT CAUGHT
# finally run
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 36
#      34 print(sep + 'EXCEPTION RAISED BUT NOT CAUGHT')
#      35 try:
# ---> 36     x = 1 / 0
#      37 except IndexError:
#      38     print('except run')
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ---

# %%
# File mergedexc.py (Python 3.X + 2.X)
sep = '-' * 45 + '\n'

print(sep + 'EXCEPTION RAISED AND CAUGHT')
try:
    x = 'spam'[99]
except IndexError:
    print('except run')
finally:
    print('finally run')
print('after run')
# Out:
# ---------------------------------------------
# EXCEPTION RAISED AND CAUGHT
# except run
# finally run
# after run

# %% [markdown]
# Pregunta si `sep` tiene la posición 99, como da IndexError porque no existe esa posición, printa `except run`, `finally run`, porque `finally` siempre se printa y `after run` porque continúa el código.

# %%
# File mergedexc.py (Python 3.X + 2.X)
sep = '-' * 45 + '\n'

print(sep + 'NO EXCEPTION RAISED')
try:
    x = 'spam'[3]
except IndexError:
    print('except run')
finally:
    print('finally run')
print('after run')
# Out:
# ---------------------------------------------
# NO EXCEPTION RAISED
# finally run
# after run

# %% [markdown]
# Pregunta `sep` tiene 3 posiciones, no da IndexError porque existe esa posición, no se ejecuta ningún `except`, se ejecuta `finally run`, porque `finally` siempre se printa, y `after run` porque continúa el código.

# %%
# File mergedexc.py (Python 3.X + 2.X)
sep = '-' * 45 + '\n'

print(sep + 'NO EXCEPTION RAISED, WITH ELSE')
try:
    x = 'spam'[3]
except IndexError:
    print('except run')
else:
    print('else run')
finally:
    print('finally run')
print('after run')
# Out:
# ---------------------------------------------
# NO EXCEPTION RAISED, WITH ELSE
# else run
# finally run
# after run

# %% [markdown]
# Pregunta si `sep` tiene 3 posiciones, no da IndexError porque existe esa posición, no se ejecuta ningún `except` antes del `else` corre `finally run` y `after run` porque continúa el código.

# %%
# File mergedexc.py (Python 3.X + 2.X)
sep = '-' * 45 + '\n'

print(sep + 'EXCEPTION RAISED BUT NOT CAUGHT')
try:
    x = 1 / 0
except IndexError:
    print('except run')
finally:
    print('finally run')
print('after run')
# Out:
# ---------------------------------------------
# EXCEPTION RAISED BUT NOT CAUGHT
# finally run
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[10], line 6
#       4 print(sep + 'EXCEPTION RAISED BUT NOT CAUGHT')
#       5 try:
# ----> 6     x = 1 / 0
#       7 except IndexError:
#       8     print('except run')
#
# ZeroDivisionError: division by zero

# %% [markdown]
# Intenta dividir `1 / 0`, en `except` deveria ser `ZeroDivisionError` como no pide esa excepción, devuelve un error y no llega a `after run`.
