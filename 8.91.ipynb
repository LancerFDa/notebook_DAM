# %%
from src.modulo import printer      # Copy out a variable (one or more) 
printer('Hello world!')             # No need to qualify name
# Hello world!
# Out:
# Hello world!

# %%
import src.modulo_simple as simple   # First import: loads and runs file's code hello
# Out:
# modulo simple

# %%
simple.spam              # the variable spam is initialized at import time
# 1
# Out:
# 1

# %%
simple.spam = 2                                 # Change attribute in module
import src.modulo_simple as simple              # Just fetches already loaded module
simple.spam                                     # Code wasn't rerun: attribute unchanged
# 2
# Out:
# 2

# %%
# modulo_small
x = 1
y = [1, 2]

# %%
from src.modulo_simple import x, y       # Copy two names out
x = 42                                  # Changes local x only
y[0] = 42                               # Changes shared mutable in place
x, y
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from src.modulo_simple import x, y       # Copy two names out
#       2 x = 42                                  # Changes local x only
#       3 y[0] = 42                               # Changes shared mutable in place
#
# ImportError: cannot import name 'x' from 'src.modulo_simple' (c:\Users\rodrg\Desktop\clase\Programacion\notebook\src\modulo_simple.py)
